# %% [markdown]
# ## Setting things up

# %% [markdown]
# ### Import libraries
# Add directory with the CIBUSmod modules to path to be able to import

# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(),'..','CIBUSmod'))

# %% [markdown]
# Import CIBUSmod and packages for handling data and plotting

# %%
import CIBUSmod as cm

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set up scenario and modules

# %%
# Create session
session = cm.Session(
    name = 'FORMAS', # <--- Make sure that name and data_path match with multi_proc.py
    data_path = '../CIBUSmod/data',
    data_path_scenarios = 'scenarios',
    data_path_output = 'output',
)
# cm.ParameterRetriever.data_path_scenarios = os.path.join('scenarios')

# Define scenarios

session.add_scenario(
    name = 'baseline',
    scenario = 'baseline', 
    modules = 'all',
    pars = 'all',
    years = 100
)
session.add_scenario(
    name = 'max_cur',
    scenario = 'max_cur', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
session.add_scenario(
    name = 'max_cur_incr',
    scenario = 'max_cur', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
session.add_scenario(
    name = 'max_cur_free',
    scenario = 'max_cur', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
session.add_scenario(
    name = 'steers',
    scenario = 'steers', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
session.add_scenario(
    name = 'steers_incr',
    scenario = 'steers', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
session.add_scenario(
    name = 'steers_free',
    scenario = 'steers', 
    modules = 'all',
    pars = 'all',
    years = np.linspace(100, 500, int( (500-100)/50 + 1) ).astype(int).tolist()
)
# Out:
# A scenario with the name 'baseline' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'max_cur' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'max_cur_incr' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'max_cur_free' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'steers' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'steers_incr' already exists use .update_scenario() or .remove_scenario() instead.
# A scenario with the name 'steers_free' already exists use .update_scenario() or .remove_scenario() instead.

# %%
session.update_scenario('max_cur', years=['100', '150', '200', '250', '300', '350', '400', '450', '500'])
session.update_scenario('steers', years=['100', '150', '200', '250', '300', '350', '400', '450', '500'])
session.update_scenario('max_cur_free', years=['100', '150', '200', '250', '300', '350', '400', '450', '500', '550', '600', '650'])
session.update_scenario('steers_free', years=['100', '150', '200', '250', '300', '350', '400', '450', '500', '550', '600', '650'])

# %%
# Import
from concurrent.futures import ProcessPoolExecutor, as_completed
from FORMAS_multi_proc_2 import do_run

# %%
# Create list of scenarios to run
runs = [(s,y) for s,y in session.iterate('all')] # ['max_cur','steers','max_cur_incr','max_cur_free','steers_incr','steers_free']
runs = sorted(runs, key=lambda x: x[1])

# %%
runs
# Out:
# [('baseline', '100'),
#  ('max_cur', '100'),
#  ('max_cur_incr', '100'),
#  ('max_cur_free', '100'),
#  ('steers', '100'),
#  ('steers_incr', '100'),
#  ('steers_free', '100'),
#  ('max_cur', '150'),
#  ('max_cur_incr', '150'),
#  ('max_cur_free', '150'),
#  ('steers', '150'),
#  ('steers_incr', '150'),
#  ('steers_free', '150'),
#  ('max_cur', '200'),
#  ('max_cur_incr', '200'),
#  ('max_cur_free', '200'),
#  ('steers', '200'),
#  ('steers_incr', '200'),
#  ('steers_free', '200'),
#  ('max_cur', '250'),
#  ('max_cur_incr', '250'),
#  ('max_cur_free', '250'),
#  ('steers', '250'),
#  ('steers_incr', '250'),
#  ('steers_free', '250'),
#  ('max_cur', '300'),
#  ('max_cur_incr', '300'),
#  ('max_cur_free', '300'),
#  ('steers', '300'),
#  ('steers_incr', '300'),
#  ('steers_free', '300'),
#  ('max_cur', '350'),
#  ('max_cur_incr', '350'),
#  ('max_cur_free', '350'),
#  ('steers', '350'),
#  ('steers_incr', '350'),
#  ('steers_free', '350'),
#  ('max_cur', '400'),
#  ('max_cur_incr', '400'),
#  ('max_cur_free', '400'),
#  ('steers', '400'),
#  ('steers_free', '400'),
#  ('max_cur', '450'),
#  ('max_cur_free', '450'),
#  ('steers', '450'),
#  ('steers_free', '450'),
#  ('max_cur', '500'),
#  ('max_cur_free', '500'),
#  ('steers', '500'),
#  ('steers_free', '500'),
#  ('max_cur_free', '550'),
#  ('steers_free', '550'),
#  ('max_cur_free', '600'),
#  ('steers_free', '600'),
#  ('max_cur_free', '650'),
#  ('steers_free', '650')]

# %%
# %%time
# Do the multi-processing
with ProcessPoolExecutor(max_workers=3) as executor:
    
    futures = {executor.submit(do_run, scn_year) : scn_year for scn_year in runs}

    for future in as_completed(futures):
    
        scn, year = futures[future]
           
        try:
            t = future.result()
        except Exception as ee:
            print(f'(!!!) {scn}, {year} failed with the exception: {ee}')
        else:
            m = int(t/60)
            s = int(round(t - m*60))
            print(f'{scn}, {year} finished successfully in {m}min {s}s')
# Out:
# max_cur, 100 finished successfully in 4min 3s
# max_cur_incr, 100 finished successfully in 4min 11s
# baseline, 100 finished successfully in 4min 12s
# max_cur_free, 100 finished successfully in 4min 7s
# steers, 100 finished successfully in 6min 10s
# steers_incr, 100 finished successfully in 7min 5s
# steers_free, 100 finished successfully in 3min 49s
# max_cur, 150 finished successfully in 3min 32s
# max_cur_incr, 150 finished successfully in 3min 35s
# max_cur_free, 150 finished successfully in 3min 38s
# steers, 150 finished successfully in 4min 42s
# steers_free, 150 finished successfully in 3min 57s
# max_cur_incr, 200 finished successfully in 4min 9s
# steers_incr, 150 finished successfully in 10min 47s
# max_cur, 200 finished successfully in 8min 9s
# max_cur_free, 200 finished successfully in 3min 49s
# steers_free, 200 finished successfully in 4min 17s
# (!!!) max_cur, 250 failed with the exception: Dropped!
# steers, 200 finished successfully in 7min 43s
# max_cur_incr, 250 finished successfully in 3min 56s
# (!!!) steers, 250 failed with the exception: Dropped!
# steers_incr, 200 finished successfully in 10min 37s
# max_cur_free, 250 finished successfully in 4min 13s
# (!!!) max_cur, 300 failed with the exception: Dropped!
# steers_free, 250 finished successfully in 4min 1s
# max_cur_incr, 300 finished successfully in 4min 17s
# (!!!) steers, 300 failed with the exception: Dropped!
# steers_incr, 250 finished successfully in 6min 6s
# max_cur_free, 300 finished successfully in 3min 41s
# (!!!) max_cur, 350 failed with the exception: Dropped!
# steers_free, 300 finished successfully in 3min 56s
# steers_incr, 300 finished successfully in 6min 50s
# (!!!) steers, 350 failed with the exception: Dropped!
# max_cur_free, 350 finished successfully in 3min 59s
# steers_free, 350 finished successfully in 4min 23s
# (!!!) max_cur, 400 failed with the exception: Dropped!
# max_cur_incr, 350 finished successfully in 11min 13s
# steers_incr, 350 finished successfully in 11min 44s
# (!!!) steers, 400 failed with the exception: Dropped!
# max_cur_free, 400 finished successfully in 4min 23s
# (!!!) max_cur, 450 failed with the exception: Dropped!
# steers_free, 400 finished successfully in 4min 8s
# (!!!) steers, 450 failed with the exception: Dropped!
# max_cur_free, 450 finished successfully in 4min 13s
# (!!!) max_cur, 500 failed with the exception: Dropped!
# steers_free, 450 finished successfully in 4min 10s
# (!!!) steers, 500 failed with the exception: Dropped!
# max_cur_free, 500 finished successfully in 4min 8s
# max_cur_incr, 400 finished successfully in 17min 46s
# steers_free, 500 finished successfully in 3min 57s
# steers_free, 550 finished successfully in 13min 20s
# max_cur_free, 550 finished successfully in 21min 21s
# (!!!) max_cur_free, 650 failed with the exception: Dropped!
# (!!!) max_cur_free, 600 failed with the exception: No solution found
# steers_free, 600 finished successfully in 47min 33s
# (!!!) steers_free, 650 failed with the exception: No solution found
# CPU times: total: 93.8 ms
# Wall time: 2h 14min 45s

# %%
fig, ax = plt.subplots(figsize=(10,5))
cm.plot.bar(
    session.get_attr('c','area',{'crop':['land_use','crop_group2']}).loc[:,'cropland']/1000000,
    ax=ax,
    group_levels = 'scn',
    sort_xlabels=False,
    sort_groups=False
)
# Out:
# (<Axes: >,
#  [<Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>])

# %%
session.get_attr('c','area','crop').loc[:,'Semi-natural pastures']/1000000
# Out:
# scn           year
# baseline      100     0.368644
# max_cur       100     0.368644
#               150     0.552967
#               200     0.589831
# max_cur_incr  100     0.368644
#               150     0.552967
#               200     0.737289
#               250     0.921611
#               300     1.105933
#               350     1.290255
#               400     1.437713
# max_cur_free  100     0.368644
#               150     0.552967
#               200     0.737289
#               250     0.921611
#               300     1.105933
#               350     1.290255
#               400     1.474578
#               450     1.658900
#               500     1.843222
#               550     1.990680
# steers        100     0.368644
#               150     0.552967
#               200     0.700424
# steers_incr   100     0.368644
#               150     0.552967
#               200     0.737289
#               250     0.921611
#               300     1.105933
#               350     1.290255
# steers_free   100     0.368644
#               150     0.552967
#               200     0.737289
#               250     0.921611
#               300     1.105933
#               350     1.290255
#               400     1.474578
#               450     1.658900
#               500     1.843222
#               550     2.027544
#               600     2.064409
# Name: Semi-natural pastures, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
cm.plot.bar(
    session.get_attr('c','area','crop').loc[:,'Semi-natural pastures']/1000000,
    ax=ax,
    group_levels='scn',
    sort_xlabels=False,
    sort_groups=False
)
# Out:
# (<Axes: >,
#  [<Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>,
#   <Axes: label='inset_axes'>])

# %% [markdown]
# ## Plot results

# %%
# Common style for plots
bar_style = {
    'cmap' : 'Pastel1',
    'edgecolor' : 'grey',
    'bar_width' : 0.6
}

bar_style_one = {
    'color' : 'lightgrey',
    'edgecolor' : 'grey'
}

map_style = {
    'cmap' : 'YlOrBr',
    'edgecolor' : 'grey'
}

map_style_r = map_style.copy()
map_style_r['cmap'] = map_style_r['cmap'] + '_r'

map_style_div = {
    'cmap' : 'BrBG',
    'edgecolor' : 'grey'
}

# Get final iteration of each scenario
scn_final = [(scn, years[-1]) for scn, years in session.scenarios('has output').items()]

# %% [markdown]
# ### Bar plots: Production and animal heads

# %%
fig, axs = plt.subplots(1,3, figsize=(8,4), width_ratios=(1,1,0.5))

plot_data = (
    session.get_attr('A','heads',['species','animal','breed'])
    .loc[scn_final,:]
    .xs('cattle', level='species', axis=1)
    .stack().droplevel('year')
    .reindex(['cows','heifers','bulls','steers','calves'], level='animal', axis=1)
)/1000

ax=axs[0]
cm.plot.bar(
    plot_data,
    ax=ax, group_levels='breed', sort_xlabels=False, sort_categories=False, **bar_style,
    ylabel='Cattle herd size [1000 heads]', ylabel_fontsize=10
)
ax.get_legend().remove()

plot_data = (
    session.get_attr('A','production',['species','animal','animal_prod', 'breed'])
    .loc[scn_final,:]
    .xs('cattle', level='species', axis=1).droplevel('year')
    .stack()
    .reindex(['cows','heifers','bulls','steers','calves'], level='animal', axis=1)
)/1000000

ax = axs[1]
cm.plot.bar(
    plot_data.xs('meat', level='animal_prod', axis=1),
    ax=ax, group_levels='breed', sort_xlabels=False, sort_categories=False, **bar_style,
    grouptitle='Breed', xlabel='Scenario', ylabel='Meat prod. [1000 tonnes C.W.]', ylabel_fontsize=10
)
ax.get_legend().remove()

ax = axs[2]
cm.plot.bar(
    plot_data.drop('beef', level='breed').xs('milk', level='animal_prod', axis=1).reindex(plot_data.columns.unique('animal'), axis=1),
    ax=ax, group_levels='breed', sort_xlabels=False, sort_categories=False, **bar_style,
    ylabel='Milk prod. [1000 tonnes]', ylabel_fontsize=10
)
ax.get_legend().remove()

fig.legend(*axs[0].get_legend_handles_labels(), loc='upper center', bbox_to_anchor=(0.5,0), ncol=5, frameon=False)
plt.tight_layout()
plt.show()

# %%
plot_data = pd.concat([
    session.get_attr('c','area',{'crop':'land_use'}).loc[:,'semi-natural grasslands'].rename('SNG')/1000000,
    cm.get_GHG(session).sum(axis=1).rename('GHG')/1000000000
], axis=1).set_index('SNG', append=True)['GHG'].unstack('scn').droplevel('year')

# %%
fig,ax = plt.subplots()
ax.axhline(y=plot_data['baseline'].dropna().values, color='black', linestyle='--', linewidth=1)
ax.axvline(x=plot_data['baseline'].dropna().index.values, color='black', linestyle='--', linewidth=1)

for col in plot_data.columns:
    if col != 'baseline':
        plot_data[col].dropna().plot(linewidth=1, marker='.')

ax.legend()
plt.show()

# %%
plot_data = (
    session.get_attr('c','production_per_use',['crop','demand'])
    .loc[:,['Ley for grazing', 'Semi-natural pastures', 'Semi-natural pastures, thin soils', 'Semi-natural pastures, wooded']]
)/1000000000
plot_data.columns = pd.MultiIndex.from_tuples(
    [(cr,) + tuple(an.replace('feed (','').replace(')','').split(', ')) for cr, an in plot_data.columns],
    names = ['crop', 'species', 'breed', 'sub_system']
)
plot_data = (
    plot_data.T.groupby(['species','breed','sub_system','crop']).sum().T
    .stack(['species','breed','sub_system'])
)
for sp,br,ss in plot_data.index.droplevel(['scn','year']).unique():
    fig,ax = plt.subplots(figsize=(12,5))
    d = plot_data.xs((sp,br,ss), level=('species','breed','sub_system')).dropna(axis=1)
    cm.plot.bar(
        d,
        ax=ax,
        group_levels=['scn'],
        sort_groups=False,
        sort_xlabels=False,
        sort_categories=False,
        grouptitle=f"{sp}, {br}, {ss}"
    )
    ax.axhline(d.loc['baseline'].sum(axis=1).iloc[0], c='black', linewidth=0.5, linestyle='--')
    plt.show()

# %%
plot_data = (
    session.get_attr('a','feed.crop_prod',['origin','crop_prod','species','breed','animal'])
    .loc[:,'domestic']
    .loc[:,'grazing']
    .stack(['species','breed'])
)/1000000000
for sp,br in plot_data.index.droplevel(['scn','year']).unique():
    fig,ax = plt.subplots(figsize=(12,5))
    d = plot_data.xs((sp,br), level=('species','breed')).dropna(axis=1)
    cm.plot.bar(
        d,
        ax=ax,
        group_levels=['scn'],
        sort_groups=False,
        sort_xlabels=False,
        sort_categories=False,
        grouptitle=f"{sp}, {br}"
    )
    ax.axhline(d.loc['baseline'].sum(axis=1).iloc[0], c='black', linewidth=0.5, linestyle='--')
    plt.show()

# %%
session.get_attr('C','production_per','species')

# %%
grazing = session.get_attr('C', 'production', ['crop_prod','crop']).loc[:,'grazing']
grazing = grazing.loc[:,grazing.sum()!=0]

plot_data1 = (
    grazing
    # .loc[SCN_NAME]
    # .rename(scn_name_map)
    /1000000000
)

plot_data2 = plot_data1.apply(lambda x: x/x.sum()*100, axis=1)

fig,axs = plt.subplots(1,2, figsize=(10,5), dpi=120)
ax=axs[0]
cm.plot.bar(plot_data1.sum(axis=1), group_levels='scn', **bar_style, ax=ax, sort_xlabels=False, sort_groups=False)
ax.axhline(y=plot_data1.sum(axis=1).loc['baseline'].iloc[0], linestyle='--', linewidth=1, color='grey')
# ax.set_ylabel('Total grazing [Mt DM]')
# ax.set_xlabel('')

ax = axs[1]
cm.plot.bar(plot_data2, group_levels='scn', **bar_style, ax=ax, sort_xlabels=False, sort_groups=False, sort_categories=False)
ax.axhline(y=plot_data2.loc['baseline','Ley for grazing'].iloc[0], linestyle='--', linewidth=1, color='grey')
# ax.legend(loc='lower left', ncol=1, bbox_to_anchor=(1, 0), fontsize=10)
# ax.set_ylabel('Share of grazing from\ndifferent pastures [%]')
# ax.set_xlabel('')

plt.tight_layout()
plt.show()

100-plot_data2.loc[:,'Ley for grazing']
# Out:
# scn           year
# baseline      100     41.906850
# max_cur       100     41.906864
#               150     61.083580
#               200     64.415998
# max_cur_incr  100     41.901215
#               150     59.562779
#               200     66.813800
#               250     70.304686
#               300     72.135064
#               350     73.759035
#               400     74.331333
# max_cur_free  100     62.482051
#               150     67.686280
#               200     70.756563
#               250     72.828108
#               300     74.590268
#               350     76.360777
#               400     77.913322
#               450     79.175836
#               500     79.541410
# steers        100     35.376497
#               150     52.066116
#               200     64.870948
# steers_incr   100     35.376191
#               150     52.051206
#               200     63.859371
#               250     69.350106
#               300     71.880611
#               350     73.381828
# steers_free   100     62.425542
#               150     67.601704
#               200     70.618563
#               250     72.638240
#               300     74.223623
#               350     75.787161
#               400     77.293951
#               450     78.687350
#               500     79.473971
# Name: Ley for grazing, dtype: float64

# %%
 session.get_attr('geo','x_crops', scn='baseline').iloc[0].loc[['Semi-natural pastures']].sum()/1000*3
# Out:
# 1105.9310944650654

# %%
import os
a=os.path.join('hej','hej')
type(a)
# Out:
# str

# %%
for x,y in enumerate(plot_data.sum(axis=1)):
    print(x)
    print(str(round(y,2)))
# Out:
# 0
# 0.8
# 1
# 0.8
# 2
# 0.82
# 3
# 0.9

# %%
list(range(len(plot_data)))
# Out:
# [0, 1, 2, 3]

# %%
fig, axs = plt.subplots(2,2, figsize=(5,7), width_ratios=(1,1))
axs = axs.flatten()

ax = axs[0]
plot_data = (
    session.get_attr('c','area',{'crop':['land_use',None]})
    .loc[scn_final,:]
    .droplevel('year')
    .loc[:,'semi-natural grasslands']
)/1000000
cm.plot.bar(plot_data, ax=ax, bar_width=0.6, sort_xlabels=False, cmap='Greens')
for x,y in enumerate(plot_data.sum(axis=1)):
    ax.text(x=x+0.5, y=y*1.05, s=str(round(y,1)), ha='center', size=9)

ax=axs[1]
plot_data = (
    session.get_attr('c','area',{'crop':['land_use','crop_group2']})
    .loc[scn_final,:]
    .droplevel('year')
    .loc[:,'cropland']
)/1000000
cm.plot.bar(plot_data, ax=ax, bar_width=0.6, sort_xlabels=False, cmap='Blues')
for x,y in enumerate(plot_data.sum(axis=1)):
    ax.text(x=x+0.5, y=y*1.05, s=str(round(y,1)), ha='center', size=9)

ax=axs[2]
plot_data = (
    session.get_attr('c','area',{'crop':['crop_group',None]})
    .loc[scn_final,:]
    .droplevel('year')
    .loc[:,'Ley']
)/1000000
cm.plot.bar(plot_data, ax=ax, bar_width=0.6, sort_xlabels=False, cmap='Oranges')
for x,y in enumerate(plot_data.sum(axis=1)):
    ax.text(x=x+0.5, y=y*1.05, s=str(round(y,1)), ha='center', size=9)

ax=axs[3]
plot_data = (
    session.get_attr('c','area',{'crop':[None]})
    .loc[scn_final,:]
    .droplevel('year')
    .loc[:,['Maize for forage and silage', 'Cereals for fodder', 'Other crops for fodder']]
)/100000
cm.plot.bar(plot_data, ax=ax, bar_width=0.6, sort_xlabels=False, cmap='Purples')
for x,y in enumerate(plot_data.sum(axis=1)):
    ax.text(x=x+0.5, y=y*1.05, s=str(round(y,1)), ha='center', size=9)

for ax in axs.flatten():
    ax.legend(loc='lower center', bbox_to_anchor=(0.5,1), frameon=False, ncol=1, fontsize=9, reverse=True)

plt.tight_layout()
plt.show()

# %%
# Out:
# [0, 1, 2, 3]

# %%
fig, axs = plt.subplots(1,3, figsize=(16,5))

plot_data = pd.concat(
    [pd.concat([
        output.loc[(scn,year),'ani']
        .heads.sum()
        .groupby(['species','animal'])
        .sum()
    ],keys=[scn],names=['scn'])
     for scn in scenarios]
)/1000

ax=axs[0]
ax.set_title('Cattle herd size [1000 heads]')
(
    plot_data
    .xs(('cattle'),level=('species'))
    .unstack()
    .plot.bar(stacked=True, ax=ax, **bar_style)
)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3),
          ncol=3, fancybox=True, shadow=True)

plot_data = pd.concat(
    [pd.concat([
        output.loc[(scn,year),'ani']
        .production.sum()
        .groupby(['species','animal','animal_prod'])
        .sum()
    ],keys=[scn],names=['scn'])
     for scn in scenarios]
)/1000000

ax = axs[1]
ax.set_title('Cattle meat production [1000 tonnes CW]')
(
    plot_data
    .xs(('cattle','meat'),level=('species','animal_prod'))
    .unstack()
    .plot.bar(stacked=True, ax=ax, **bar_style)
)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3),
          ncol=3, fancybox=True, shadow=True)

ax = axs[2]
ax.set_title('Cattle milk production [1000 tonnes ECM]')
(
    plot_data
    .xs(('cattle','milk','cows'),level=('species','animal_prod','animal'))
    .plot.bar(stacked=True, ax=ax, **bar_style_one)
)

plt.show()

# %% [markdown]
# ### Bar plots: GHG and land use

# %%
fig, axs = plt.subplots(1,3, figsize=(16,5)) # , gridspec_kw={'width_ratios': [1, 2]})
rel = cm.ParameterRetriever.get_rel('crop','land_use')

plot_data = (
    get_GHG(output)
    .sum()
    .groupby(['scn','process'])
    .sum()
    .unstack()
    /1000000
)
ax = axs[0]
plot_data.plot.bar(stacked=True, ax = ax, **bar_style)
ax.set_title('Agricultural GHG emissions [1000 tonnes CO2-eq]')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3),
          ncol=2, fancybox=True, shadow=True)

plot_data = pd.concat(
    [pd.concat([output.loc[(scn,year),'crp'].area.rename(rel).groupby('crop').sum()],keys=[scn],names=['scn'])
     for scn in scenarios]
)/1000

ax = axs[1]
plot_data.xs('semi-natural grasslands',level='crop').plot.bar(ax = ax, **bar_style_one)
ax.set_title('Semi-natural grassland area [1000 ha]')

ax = axs[2]
plot_data.xs('cropland',level='crop').plot.bar(ax = ax, **bar_style_one)
ax.set_title('Cropland area [1000 ha]')

plt.show()

# %% [markdown]
# ### Maps: Land use and cattle numbers

# %%
plot_data = (
    session.get_attr('c','area',{'crop':'land_use', 'region':None})
    .loc[scn_final,:]
    .transform(lambda x: x.sub(x.loc[('baseline','100')],axis=1))
    .drop(('baseline','100'))
    .droplevel('year')
)/1000


n_scn = len(plot_data)
lims = plot_data.T.abs().groupby('land_use').max().max(axis=1)

# fig,axs = plot.subplots(plot_data.T.drop('greenhouse'),
#                         size=(2.5,4), columns='scn', index='land_use', title_fontsize=11,
#                         plot_fn=plot.map_from_series,
#                         cmap_zero_midpoint=False, **map_style_div, vmax=8, vmin=-8)
# for ax in axs.flatten():
#     ax.axis('off')
# plt.tight_layout()
# plt.show()

fig = plt.figure(layout='constrained', figsize=(2.2*n_scn, 8))
subfigs = fig.subfigures(2, 1, wspace=0.07)

# Semi-natural grasslands
axs1 = subfigs[0].subplots(1,n_scn)
for n, scn in enumerate(plot_data.index):
    ax = axs1[n]
    cm.plot.map_from_series(
        plot_data.loc[scn,'semi-natural grasslands'],
        ax = ax,
        # vmin=-lims.loc['semi-natural grasslands'],
        cmap_zero_midpoint='shrink',
        # vmax=lims.loc['semi-natural grasslands'],
        **map_style_div
    )
    ax.set_title(scn, size=10)
    ax.axis('off')
subfigs[0].suptitle('Change in semi-natural grassland area [1000 ha]', size=11)

# Cropland
axs2 = subfigs[1].subplots(1,n_scn)
# fig, axs = plt.subplots(1,n_scn, figsize=(2.2*n_scn,4))
for n, scn in enumerate(plot_data.index):
    ax = axs2[n]
    cm.plot.map_from_series(
        plot_data.loc[scn,'cropland'],
        ax = ax,
        # vmin=-lims.loc['cropland'],
        cmap_zero_midpoint='shrink',
        # vmax=lims.loc['cropland'],
        **map_style_div
    )
    ax.set_title(scn, size=10)
    ax.axis('off')
subfigs[1].suptitle('Change in cropland area [1000 ha]', size=11)
# fig.tight_layout()
plt.show()

# %%
n_scn = len(scenarios)-1
fig, axs = plt.subplots(1,n_scn, figsize=(4*n_scn,7))
n=0
for scn in list(scenarios.keys())[1:]:
    plot_data = (
        output.loc[(scn,year),'ani'].heads.xs(('cattle','dairy'), axis=1).sum(axis=1) -
        output.loc[('baseline',year),'ani'].heads.xs(('cattle','dairy'), axis=1).sum(axis=1)
    )/1000
    ax = axs[n]
    plot.map_from_series(
        plot_data,
        ax = ax,
        vmin=-5,
        vmax=5,
        **map_style_div
    )
    ax.set_title(scn)
    n += 1
plt.suptitle('Change in total number of cattle in dairy herds [1000 heads]', size=14)
plt.show()

fig, axs = plt.subplots(1,n_scn, figsize=(4*n_scn,7))
n=0
for scn in list(scenarios.keys())[1:]:
    plot_data = (
        output.loc[(scn,year),'ani'].heads.xs(('cattle','beef'), axis=1).sum(axis=1) -
        output.loc[('baseline',year),'ani'].heads.xs(('cattle','beef'), axis=1).sum(axis=1)
    )/1000
    ax = axs[n]
    plot.map_from_series(
        plot_data,
        ax = ax,
        vmin=-5,
        vmax=5,
        **map_style_div
    )
    ax.set_title(scn)
    n += 1
plt.suptitle('Change in total number of cattle in beef herds [1000 heads]', size=14)
plt.show()

# %% [markdown]
# ### Feed rations

# %%
feed_rations = (
    (
        output.loc[('baseline',year),'ani'].feed.consumption.sum().groupby(['species','breed','animal','feed']).sum() /
        output.loc[('baseline',year),'ani'].heads.sum().groupby(['species','breed','animal']).sum()
    )
    .unstack(['species','breed','animal'])
    .loc[:,'cattle']
    .dropna(how='all')
    .dropna(how='all', axis=1)
)

feed_rations.to_clipboard()
feed_rations
# Out:
# breed                               beef                           \
# animal                             bulls      calves         cows
# feed
# barley                        732.466575    0.000000     0.000000
# broad beans                    60.671369    0.000000     0.000000
# grazing                         0.000000  441.759559  2001.138084
# ley silage, 1st cut          2722.415598    0.000000     0.000000
# ley silage, regrowth            0.000000  999.717284   676.978922
# luzern meal                     0.310046    0.000000     0.000000
# maize                           1.036433    0.000000     0.000000
# maize silage                  147.378130    0.000000     0.000000
# minerals                        5.307731    0.000000     0.000000
# oats                          151.370789    0.000000     0.000000
# other silage                    0.000000    0.000000   700.531662
# palm kernel expeller            3.981597    0.000000     0.000000
# peas                           62.862692    0.000000     0.000000
# potatoe protein                 0.034450    0.000000     0.000000
# rapeseed                       17.445274    0.000000     0.000000
# rapeseed meal                  13.881758    0.000000     0.000000
# rye                             0.000000    0.000000     0.000000
# soybean meal                    5.115897    0.000000     0.000000
# soybeans                        2.013668    0.000000     0.000000
# straw                           0.000000    0.000000   700.531662
# sugar beet molasses             2.884709    0.000000     0.000000
# sugar beet pulp                 5.192475    0.000000     0.000000
# sunflower seed meal             0.499998    0.000000     0.000000
# triticale                     277.949303    0.000000     0.000000
# vegetable oils                  2.850956    0.000000     0.000000
# wheat                         362.280964    0.000000     0.000000
# wheat bran                     11.685997    0.000000     0.000000
# wheat distillers grain, dry     4.905483    0.000000     0.000000
#
# breed                                                        dairy  \
# animal                           heifers       steers        bulls
# feed
# barley                          0.000000     0.000000   425.235617
# broad beans                     0.000000     0.000000    33.656268
# grazing                       895.345250   914.838488     0.000000
# ley silage, 1st cut             0.000000     0.000000  1924.021225
# ley silage, regrowth         2026.197517  2070.311393     0.000000
# luzern meal                     0.000000     0.000000     0.268115
# maize                           0.000000     0.000000     0.896264
# maize silage                    0.000000     0.000000   123.104324
# minerals                        0.000000     0.000000     4.589906
# oats                            0.000000     0.000000    87.878755
# other silage                    0.000000     0.000000     0.000000
# palm kernel expeller            0.000000     0.000000     3.443121
# peas                            0.000000     0.000000    34.544973
# potatoe protein                 0.000000     0.000000     0.029791
# rapeseed                        0.000000     0.000000    15.085951
# rapeseed meal                   0.000000     0.000000    12.004370
# rye                             0.000000     0.000000     0.000000
# soybean meal                    0.000000     0.000000     4.424016
# soybeans                        0.000000     0.000000     1.741337
# straw                           0.000000     0.000000     0.000000
# sugar beet molasses             0.000000     0.000000     2.494577
# sugar beet pulp                 0.000000     0.000000     4.490238
# sunflower seed meal             0.000000     0.000000     0.432377
# triticale                       0.000000     0.000000   159.820548
# vegetable oils                  0.000000     0.000000     2.465389
# wheat                           0.000000     0.000000   211.867010
# wheat bran                      0.000000     0.000000    10.105566
# wheat distillers grain, dry     0.000000     0.000000     4.242059
#
# breed
# animal                           calves         cows      heifers       steers
# feed
# barley                        36.863224   827.059431    54.238062    63.367730
# broad beans                    0.766876    17.646600     1.128330     1.318257
# grazing                      636.493398   683.296171   936.493455  1094.129509
# ley silage, 1st cut            0.000000  2241.392161     0.000000     0.000000
# ley silage, regrowth         907.052363   631.256558  1334.575667  1559.219247
# luzern meal                    0.061336     3.636660     0.090245     0.105436
# maize                          0.205035    12.156752     0.301675     0.352455
# maize silage                   0.000000   326.608762     0.000000     0.000000
# minerals                       1.050018    62.256599     1.544925     1.804976
# oats                           7.618116   170.919251    11.208782    13.095510
# other silage                   0.000000     0.000000     0.000000     0.000000
# palm kernel expeller           0.787671    46.701825     1.158927     1.354004
# peas                           0.599315     6.223302     0.881791     1.030219
# potatoe protein                0.006815     0.404073     0.010027     0.011715
# rapeseed                       3.451164   204.622938     5.077810     5.932536
# rapeseed meal                  2.746201   162.824970     4.040574     4.720708
# rye                            0.000000     0.000000     0.000000     0.000000
# soybean meal                   1.012068    60.006507     1.489088     1.739740
# soybeans                       0.398360    23.619158     0.586120     0.684779
# straw                          0.000000   180.990582     0.000000     0.000000
# sugar beet molasses            0.570676    33.835958     0.839654     0.980990
# sugar beet pulp                1.027217    60.904724     1.511378     1.765782
# sunflower seed meal            0.098914     5.864682     0.145535     0.170032
# triticale                     13.187313   311.757923    19.402922    22.668936
# vegetable oils                 0.563999    33.440064     0.829830     0.969512
# wheat                         19.033887   411.153535    28.005178    32.719174
# wheat bran                     2.311817   137.069959     3.401452     3.974005
# wheat distillers grain, dry    0.970442    57.538474     1.427843     1.668186
